# %% [markdown]
# <a href="https://colab.research.google.com/github/Sviraj/First-React-App/blob/main/Untitled5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
df = pd.read_csv('sample_data/user_data_batch 16.csv')
df
# Out:
#                                                 login        id  \
# 0                                          Kirisanthi  39005450
# 1                                           mathula31  84310726
# 2                                           ChameeraD  27477126
# 3                                         VidyaWaruni  38793156
# 4                                              nir099  33232105
# ..                                                ...       ...
# 81                                            nadunij  33217969
# 82  sujeewakabeysinghe,36567954,MDQ6VXNlcjM2NTY3OT...       NaN
# 83                                    dilanichristina  39005479
# 84                                          AshfakMRM  39162550
# 85                                    YohanKulasinghe  28680211
#
#                  node_id                                         avatar_url  \
# 0   MDQ6VXNlcjM5MDA1NDUw  https://avatars.githubusercontent.com/u/390054...
# ...

# %%
desired_column = df['login']

# Display the extracted column
print(desired_column.head(20))
# Out:
# 0                                            Kirisanthi
# 1                                             mathula31
# 2                                             ChameeraD
# 3                                           VidyaWaruni
# 4                                                nir099
# 5                                              Suhadini
# 6                                     ashinkaranasinghe
# 7                                             tamaliudk
# 8                                       BimsaraFernando
# 9                                   TharinduniKaushalya
# 10                                        widuranga1996
# 11                                               Dumika
# 12                                     pavithradilshani
# 13                                           chandukasm
# 14                                        shameelashker
# 15    HeshanDSilva,44609288,MDQ6VXNlcjQ0NjA5Mjg4,htt...
# 16                                     IshaniDasanayake
# ...

# %%
array_data = desired_column.values

# Display the array
print(array_data)
# Out:
# ['Kirisanthi' 'mathula31' 'ChameeraD' 'VidyaWaruni' 'nir099' 'Suhadini'
#  'ashinkaranasinghe' 'tamaliudk' 'BimsaraFernando' 'TharinduniKaushalya'
#  'widuranga1996' 'Dumika' 'pavithradilshani' 'chandukasm' 'shameelashker'
# ...
